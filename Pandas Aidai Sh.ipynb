# %% [markdown]
# # Pandas Basics
#
# This [documentation](https://pandas.pydata.org/docs/getting_started/index.html) may be helpful throughout these exercises.
# ### Dataset Loading
# Download the .csv file from this [link](https://www.kaggle.com/datasets/shivamb/netflix-shows). You may need to create a free Kaggle account to do this. Load it as a dataframe using pandas.

# %%
import pandas as pd
dataframe=pd.read_csv('netflix_titles.csv')
dataframe
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Write some code to take a look at the first 10 rows of the dataset. Do you notice anything wrong with the dataset?

# %%
dataframe.iloc[:10,:]
# a lot of undefined values
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# ### Dataset Cleaning
# There are many issues that exist in this dataset, but we will focus on a few. In practice, you should perform a more extensive data cleaning.
#
# How many different datatypes exists in the DataFrame? What are they?

# %%
dataframe.dtypes
# object and int dtype?
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# Write some code to convert the data_added column into datetime and save it back to the original DataFrame.

# %%
dataframe['date_added'] = pd.to_datetime(dataframe['date_added'])
dataframe.to_csv('netflix_titles.csv', index=False)

# %% [markdown]
# Write some code to determine how many null values exists in each column. How many columns have null values?

# %%
dataframe.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Which column has the highest percentage of null values? What is the percentage?

# %%
null_percentages = dataframe.isnull().sum() / len(dataframe) * 100
max_null_percent = null_percentages.max()
print(f'The highest percentage is \'director\', {max_null_percent:.2f}%')
# Out:
# The highest percentage is 'director', 29.91%

# %% [markdown]
# The way we handle null values depends on how valuable the columns and rows are to us, and the datatype.
#
# Since the director column could be important to our downstream analysis, we want to keep the column. However, we need to deal with the null values. In this case, since it is a string column, let us replace the null values with the empty string. Replace the null values in the original dataset.

# %%
dataframe['director'].fillna('', inplace=True)
dataframe
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans
# 4         s5  TV Show           Kota Factory
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %% [markdown]
# Now, let's focus on some of the issues that we see in the rating column.
#
# Take a closer look at the values in this column. You might find there are values that do not belong. Identify these values and put them in the appropriate column.

# %%
dataframe[(dataframe['rating'] =='74 min')|(dataframe['rating'] =='84 min')|(dataframe['rating'] =='66 min')]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %% [markdown]
# There is a lot more cleaning that we can do, but we will leave the dataset as if for now.

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# What is the average (rounded) release year for the Netflix titles listed?

# %%
print(round(dataframe['release_year'].mean()))
# Out:
# 2014

# %% [markdown]
# Which country has the highest number of movie titles? What is that number? What is the percentage of all movies?

# %%
movies_by_country = dataframe.groupby('country')['title'].count()

max_movies_country = movies_by_country.idxmax()
max_movies_count = movies_by_country[max_movies_country]

total_movies = dataframe['title'].count()
max_movies_percent = (max_movies_count / total_movies) * 100

print(f'The country with the highest number of movie titles is {max_movies_country} with {max_movies_count} titles.')
print(f'This represents {max_movies_percent:.2f}% of all {total_movies} movies in the dataset.')
# Out:
# The country with the highest number of movie titles is United States with 2818 titles.
# This represents 32.00% of all 8807 movies in the dataset.

# %% [markdown]
# ### Store sales data
# For the last part of these exercises we will use a dataset with more numerical features. Please load the `Stores.csv` dataset.

# %% [markdown]
# Create a histogram for each of the columns, except store ID. What do you notice in common across all the historgram, especially the shape?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Stores.csv')
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
df = df.drop("Store ID ", axis=1)
df
# Out:
#      Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1659             1961                   530        66490
# 1          1461             1752                   210        39820
# 2          1340             1609                   720        54010
# 3          1451             1748                   620        53730
# 4          1770             2111                   450        46620
# ..          ...              ...                   ...          ...
# 891        1582             1910                  1080        66390
# 892        1387             1663                   850        82080
# 893        1200             1436                  1060        76440
# 894        1299             1560                   770        96610
# 895        1174             1429                  1110        54340
#
# [896 rows x 4 columns]

# %%
df.hist(bins=10, figsize=(10,10))
plt.show()

# %% [markdown]
# Find the correlations between all columns in the dataset, except store ID. What variables have a high correlation? Does this make sense?

# %%
df.corr()
#The distribution of histograms are Normal, but I think Store_Area & Items_Available have a high correlation
# Out:
#                       Store_Area  Items_Available  Daily_Customer_Count  \
# Store_Area              1.000000         0.998891             -0.041423
# Items_Available         0.998891         1.000000             -0.040978
# Daily_Customer_Count   -0.041423        -0.040978              1.000000
# Store_Sales             0.097474         0.098849              0.008629
#
#                       Store_Sales
# Store_Area               0.097474
# Items_Available          0.098849
# Daily_Customer_Count     0.008629
# Store_Sales              1.000000

# %% [markdown]
# Which columns' correlations were you most surprised about?

# %%
#The correlation between Store_Area & Items_Available are almost same

# %% [markdown]
# # Congratulations! You are well on your way to being a data scientist!
